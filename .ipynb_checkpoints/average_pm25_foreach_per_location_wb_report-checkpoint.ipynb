# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
# %matplotlib inline
import matplotlib.dates as mdates
import re
import os
import datetime
import warnings

# %%
base_dir ='data\AirQuality\AirQo'
#average_pm25_concentrations_foreach_hour_for_different_locations = pd.read_csv(os.path.join(base_dir,'average_pm25_concentration_for_each_hour_of_day_for_different_locations_a.csv'))
average_pm25_concentrations_foreach_hour_for_different_locations = pd.read_csv(os.path.join(base_dir,'average_pm25_concentration_for_each_hour_of_day_for_different_locations_report_wb.csv'))
#average_pm25_concentrations_foreach_hour_for_different_locations = pd.read_csv(os.path.join(base_dir,'average_pm25_concentration_for_each_hour_of_day_for_different_locations.csv'))
average_pm25_concentrations_foreach_hour_for_different_locations.head()
# Out:
#       Hour  PM2.5(Ug/m3)_Mukono  PM2.5(Ug/m3)_Rubaga  PM2.5(Ug/m3)_Kireka  \
# 0  0:00:00                35.42                46.85               145.96
# 1  1:00:00                32.28                43.02               115.00
# 2  2:00:00                29.97                38.26                90.67
# 3  3:00:00                32.54                35.18                73.54
# 4  4:00:00                34.12                38.33                67.91
#
#    PM2.5(Ug/m3)_Bweyogerere  PM2.5(Ug/m3)_Seguku  PM2.5(Ug/m3)_Bunamwaya  \
# 0                     73.86                43.97                   50.34
# 1                     54.13                39.08                   46.42
# 2                     48.84                35.47                   41.54
# 3                     45.44                33.96                   39.23
# 4                     46.32                35.16                   38.43
#
#    PM2.5(Ug/m3)_Kawempe
# 0                 68.16
# 1                 57.85
# 2                 53.71
# 3                 48.54
# 4                 46.93

# %%
average_pm25_concentrations_foreach_hour_for_different_locations['Hour']= pd.to_timedelta(average_pm25_concentrations_foreach_hour_for_different_locations['Hour'],unit='h')
average_pm25_concentrations_foreach_hour_of_day= average_pm25_concentrations_foreach_hour_for_different_locations.set_index('Hour')

# %%
current_date = datetime.datetime.now()
average_pm25_concentrations_foreach_hour_of_day['Date'] = pd.to_datetime(current_date.strftime('%Y-%m-%d')) 
average_pm25_concentrations_foreach_hour_of_day['Time(hrs)']= average_pm25_concentrations_foreach_hour_of_day.index
average_pm25_concentrations_foreach_hour_of_day['Time(hrs)']
average_pm25_concentrations_foreach_hour_of_day[['Date','Time(hrs)']].dtypes
average_pm25_concentrations_foreach_hour_of_day['TimeStamp']  = average_pm25_concentrations_foreach_hour_of_day['Date']+ average_pm25_concentrations_foreach_hour_of_day['Time(hrs)']
average_pm25_concentrations_foreach_hour_of_day.head()
# Out:
#           PM2.5(Ug/m3)_Mukono  PM2.5(Ug/m3)_Rubaga  PM2.5(Ug/m3)_Kireka  \
# Hour
# 00:00:00                35.42                46.85               145.96
# 01:00:00                32.28                43.02               115.00
# 02:00:00                29.97                38.26                90.67
# 03:00:00                32.54                35.18                73.54
# 04:00:00                34.12                38.33                67.91
#
#           PM2.5(Ug/m3)_Bweyogerere  PM2.5(Ug/m3)_Seguku  \
# Hour
# 00:00:00                     73.86                43.97
# 01:00:00                     54.13                39.08
# 02:00:00                     48.84                35.47
# 03:00:00                     45.44                33.96
# 04:00:00                     46.32                35.16
#
#           PM2.5(Ug/m3)_Bunamwaya  PM2.5(Ug/m3)_Kawempe       Date Time(hrs)  \
# Hour
# 00:00:00                   50.34                 68.16 2019-06-14  00:00:00
# 01:00:00                   46.42                 57.85 2019-06-14  01:00:00
# 02:00:00                   41.54                 53.71 2019-06-14  02:00:00
# 03:00:00                   39.23                 48.54 2019-06-14  03:00:00
# 04:00:00                   38.43                 46.93 2019-06-14  04:00:00
#
#                    TimeStamp
# Hour
# 00:00:00 2019-06-14 00:00:00
# 01:00:00 2019-06-14 01:00:00
# 02:00:00 2019-06-14 02:00:00
# 03:00:00 2019-06-14 03:00:00
# 04:00:00 2019-06-14 04:00:00

# %%
def show_dataframe_info(df):
    print(df.shape)
    print(list(df.columns.values))
    print('\n dataframe info: \n', df.info())
    print('\n dataframe column datatypes:\n', df.dtypes)

# %%
#show_dataframe_info(average_pm25_concentrations_foreach_hour)

# %%
average_pm25_concentrations_foreach_hour_for_different_locations.head()
# Out:
#       Hour  PM2.5(Ug/m3)_Mukono  PM2.5(Ug/m3)_Rubaga  PM2.5(Ug/m3)_Kireka  \
# 0 00:00:00                35.42                46.85               145.96
# 1 01:00:00                32.28                43.02               115.00
# 2 02:00:00                29.97                38.26                90.67
# 3 03:00:00                32.54                35.18                73.54
# 4 04:00:00                34.12                38.33                67.91
#
#    PM2.5(Ug/m3)_Bweyogerere  PM2.5(Ug/m3)_Seguku  PM2.5(Ug/m3)_Bunamwaya  \
# 0                     73.86                43.97                   50.34
# 1                     54.13                39.08                   46.42
# 2                     48.84                35.47                   41.54
# 3                     45.44                33.96                   39.23
# 4                     46.32                35.16                   38.43
#
#    PM2.5(Ug/m3)_Kawempe
# 0                 68.16
# 1                 57.85
# 2                 53.71
# 3                 48.54
# 4                 46.93

# %% [raw]
#     #y_axis_values = average_pm25_concentration_for_each_hour_of_day['PM2.5(Ug/m3)'].values
#     #x_axis_values = average_pm25_concentration_for_each_hour_of_day['TimeStamp'].values
#     plt.rcParams.update({'font.size':14, 'font.weight':'bold'})
#     x_axis_label = 'Time(Hours)'
#     y_axis_label =  'PM2.5 Concentration(ug/m3)'
#     chart_title  =  'Average PM2.5 foreach Hour for the different locations'
#     file_path    =   os.path.join(base_dir , 'average_pm25_foreach_hour_for_different_locations.png')
#
#     fig = plt.figure(figsize=(12,14))
#     plt.rcParams.update({'font.size':16, 'font.weight':'bold'})
#     ax = fig.add_subplot(111)
#     plt.plot(average_pm25_concentrations_foreach_hour_of_day['TimeStamp'].values,
#              average_pm25_concentrations_foreach_hour_of_day['PM2.5(Ug/m3)_Lubowa'].values,
#              color='', marker='d', linestyle='solid',  label='Average PM2.5 foreach Hour in Lubowa', linewidth=1.5,markersize=12)
#
#     plt.plot(average_pm25_concentrations_foreach_hour_of_day['TimeStamp'].values,
#              average_pm25_concentrations_foreach_hour_of_day['PM2.5(Ug/m3)_Rubaga'].values,
#              color='black', marker='P', linestyle='solid',  label='Average PM2.5 foreach Hour in Rubaga', linewidth=2.0,markersize=12)
#
#     plt.plot(average_pm25_concentrations_foreach_hour_of_day['TimeStamp'].values,
#              average_pm25_concentrations_foreach_hour_of_day['PM2.5(Ug/m3)_Kireka'].values,
#              color='blue', marker='o', linestyle='solid',  label='Average PM2.5 foreach Hour in Kireka', linewidth=2.0,markersize=12)
#
#     plt.plot(average_pm25_concentrations_foreach_hour_of_day['TimeStamp'].values,
#              average_pm25_concentrations_foreach_hour_of_day['PM2.5(Ug/m3)_JinjaRoad'].values,
#              color='darkcyan', marker='*', linestyle='solid',  label='Average PM2.5 foreach Hour on JinjaRoad',linewidth=2.0, markersize=12)
#
#     plt.plot(average_pm25_concentrations_foreach_hour_of_day['TimeStamp'].values,
#              average_pm25_concentrations_foreach_hour_of_day['PM2.5(Ug/m3)_Nsambya'].values,
#              color='midnightblue', marker='p', linestyle='dashed',  label='Average PM2.5 foreach Hour in Nsambya',linewidth=2.0, markersize=12)
#
#     plt.title(chart_title, fontsize=20)
#     plt.ylabel(y_axis_label, fontsize=20)
#     plt.xlabel(x_axis_label,fontsize=20)
#
#     hours = mdates.HourLocator(interval = 1)
#     hour_format = mdates.DateFormatter('%H:%M')
#     ax.xaxis.set_major_locator(hours)
#     ax.xaxis.set_major_formatter(hour_format)
#     #ax.set_xticklabels(rotation='vertical', fontsize=14)
#     plt.xticks(rotation=90)
#     ##coloring
#     ax.axhspan(0, 12, facecolor='green')
#     ax.axhspan(12, 35.4, facecolor='yellow')
#     ax.axhspan(35.4, 55.4, facecolor='orange')
#     ax.axhspan(55.4, 150.4, facecolor='red')
#     ax.axhspan(150.4, 250.4, facecolor='purple')
#     ax.axhspan(250.4, 350.4, facecolor='maroon')
#     plt.legend()
#     plt.show()
#     fig.savefig(file_path)

# %% [raw]
#     #y_axis_values = average_pm25_concentration_for_each_hour_of_day['PM2.5(Ug/m3)'].values
#     #x_axis_values = average_pm25_concentration_for_each_hour_of_day['TimeStamp'].values
#     plt.rcParams.update({'font.size':14, 'font.weight':'bold'})
#     x_axis_label = 'Time(Hours)'
#     y_axis_label =  'PM2.5 Concentration(ug/m3)'
#     chart_title  =  'Average PM2.5 foreach Hour for the different locations'
#     file_path    =   os.path.join(base_dir , 'average_pm25_foreach_hour_for_different_locations_a_b.png')
#
#     fig = plt.figure(figsize=(12,10))
#     plt.rcParams.update({'font.size':16, 'font.weight':'bold'})
#     ax = fig.add_subplot(111)
#     plt.plot(average_pm25_concentrations_foreach_hour_of_day['TimeStamp'].values,
#              average_pm25_concentrations_foreach_hour_of_day['PM2.5(Ug/m3)_Makerere'].values,
#              color='navy', marker='o', linestyle='solid',  label='Average PM2.5 foreach Hour in Makerere', linewidth=2.0,markersize=12)
#
#     plt.plot(average_pm25_concentrations_foreach_hour_of_day['TimeStamp'].values,
#              average_pm25_concentrations_foreach_hour_of_day['PM2.5(Ug/m3)_Bugolobi'].values,
#              color='black', marker='P', linestyle='solid',  label='Average PM2.5 foreach Hour in Bugolobi', linewidth=2.0,markersize=12)
#
#     plt.plot(average_pm25_concentrations_foreach_hour_of_day['TimeStamp'].values,
#              average_pm25_concentrations_foreach_hour_of_day['PM2.5(Ug/m3)_Mulago'].values,
#              color='deeppink', marker='d', linestyle='solid',  label='Average PM2.5 foreach Hour in Mulago', linewidth=2.0,markersize=12)
#
#     plt.plot(average_pm25_concentrations_foreach_hour_of_day['TimeStamp'].values,
#              average_pm25_concentrations_foreach_hour_of_day['PM2.5(Ug/m3)_Makindye'].values,
#              color='darkcyan', marker='*', linestyle='solid',  label='Average PM2.5 foreach Hour in Makindye',linewidth=2.0, markersize=12)
#
#     plt.plot(average_pm25_concentrations_foreach_hour_of_day['TimeStamp'].values,
#              average_pm25_concentrations_foreach_hour_of_day['PM2.5(Ug/m3)_Bukoto'].values,
#              color='blue', marker='p', linestyle='dashed',  label='Average PM2.5 foreach Hour in Bukoto',linewidth=2.0, markersize=12)
#
#     plt.title(chart_title, fontsize=20)
#     plt.ylabel(y_axis_label, fontsize=20)
#     plt.xlabel(x_axis_label,fontsize=20)
#
#     hours = mdates.HourLocator(interval = 1)
#     hour_format = mdates.DateFormatter('%H:%M')
#     ax.xaxis.set_major_locator(hours)
#     ax.xaxis.set_major_formatter(hour_format)
#     #ax.set_xticklabels(rotation='vertical', fontsize=14)
#     plt.xticks(rotation=90)
#     ##coloring
#     ax.axhspan(0, 12, facecolor='green')
#     ax.axhspan(12, 35.4, facecolor='yellow')
#     ax.axhspan(35.4, 55.4, facecolor='orange')
#     #ax.axhspan(55.4, 150.4, facecolor='red')
#     #ax.axhspan(150.4, 250.4, facecolor='purple')
#     #ax.axhspan(250.4, 350.4, facecolor='maroon')
#     plt.legend()
#     plt.show()
#     fig.savefig(file_path)

# %%
    #y_axis_values = average_pm25_concentration_for_each_hour_of_day['PM2.5(Ug/m3)'].values
    #x_axis_values = average_pm25_concentration_for_each_hour_of_day['TimeStamp'].values
    plt.rcParams.update({'font.size':14, 'font.weight':'bold'})
    x_axis_label = 'Time(Hours)'
    y_axis_label =  'PM2.5 Concentration(ug/m3)'
    chart_title  =  'Average PM2.5 foreach hour for different locations'
    file_path    =   os.path.join(base_dir , 'average_pm25_foreach_hour_for_different_locations_wb.png')
    
    fig = plt.figure(figsize=(12,14))
    plt.rcParams.update({'font.size':16, 'font.weight':'bold'})
    ax = fig.add_subplot(111)
    plt.plot(average_pm25_concentrations_foreach_hour_of_day['TimeStamp'].values, 
             average_pm25_concentrations_foreach_hour_of_day['PM2.5(Ug/m3)_Mukono'].values, 
             color='deeppink', marker='d', linestyle='solid',  label='Average PM2.5 foreach Hour in Mukono(Central)', linewidth=1.5,markersize=12)
    
    plt.plot(average_pm25_concentrations_foreach_hour_of_day['TimeStamp'].values, 
             average_pm25_concentrations_foreach_hour_of_day['PM2.5(Ug/m3)_Rubaga'].values, 
             color='black', marker='P', linestyle='solid',  label='Average PM2.5 foreach Hour in Rubaga', linewidth=1.5,markersize=12)
    
    plt.plot(average_pm25_concentrations_foreach_hour_of_day['TimeStamp'].values, 
             average_pm25_concentrations_foreach_hour_of_day['PM2.5(Ug/m3)_Kireka'].values, 
             color='blue', marker='o', linestyle='solid',  label='Average PM2.5 foreach Hour in Namugongo(Kireka)', linewidth=1.5,markersize=12)
    
    plt.plot(average_pm25_concentrations_foreach_hour_of_day['TimeStamp'].values, 
             average_pm25_concentrations_foreach_hour_of_day['PM2.5(Ug/m3)_Bweyogerere'].values, 
             color='darkcyan', marker='*', linestyle='solid',  label='Average PM2.5 foreach Hour in Bweyogerere',linewidth=1.5, markersize=12)
    
    plt.plot(average_pm25_concentrations_foreach_hour_of_day['TimeStamp'].values, 
             average_pm25_concentrations_foreach_hour_of_day['PM2.5(Ug/m3)_Seguku'].values, 
             color='midnightblue', marker='p', linestyle='dashed',  label='Average PM2.5 foreach Hour in Ndejje(Seguku)',linewidth=1.5, markersize=12)
    
    plt.plot(average_pm25_concentrations_foreach_hour_of_day['TimeStamp'].values, 
             average_pm25_concentrations_foreach_hour_of_day['PM2.5(Ug/m3)_Bunamwaya'].values, 
             color='darkturquoise', marker='*', linestyle='solid',  label='Average PM2.5 foreach Hour in Bunamwaya',linewidth=1.5, markersize=12)
    
    plt.plot(average_pm25_concentrations_foreach_hour_of_day['TimeStamp'].values, 
             average_pm25_concentrations_foreach_hour_of_day['PM2.5(Ug/m3)_Kawempe'].values, 
             color='lawngreen', marker='p', linestyle='dashed',  label='Average PM2.5 foreach Hour in Kawempe',linewidth=1.5, markersize=12)
    
    plt.title(chart_title, fontsize=20)
    plt.ylabel(y_axis_label, fontsize=20)
    plt.xlabel(x_axis_label,fontsize=20)
    
    hours = mdates.HourLocator(interval = 1)
    hour_format = mdates.DateFormatter('%H:%M')
    ax.xaxis.set_major_locator(hours)
    ax.xaxis.set_major_formatter(hour_format)
    #ax.set_xticklabels(rotation='vertical', fontsize=14)
    plt.xticks(rotation=90)
    ##coloring
    ax.axhspan(0, 12, facecolor='green')
    ax.axhspan(12, 35.4, facecolor='yellow')
    ax.axhspan(35.4, 55.4, facecolor='orange')
    ax.axhspan(55.4, 150.4, facecolor='red')
    ax.axhspan(150.4, 250.4, facecolor='purple')
    ax.axhspan(250.4, 350.4, facecolor='maroon')
    plt.legend()
    plt.show()
    fig.savefig(file_path)
